# %% [markdown]
# <a href="https://colab.research.google.com/github/swchae516/AI/blob/master/1%EC%A3%BC%EC%B0%A8_%EA%B3%BC%EC%A0%9C.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1. 언어
# 인공지능은 인간의 지능을 본 따 만들어진 고급 컴퓨터 프로그램을 의미한다. 최근 인공지능이 인간처럼 생각하고, 학습, 판단하여 논리적으로 결과를 끌어낼 수 있도록 5G 첨단기술을 활용한 머신러닝, 딥러닝, 등을 통해 학습시킴에 따라 인공지능이 인간을 대신하여 처리하는 일들이 늘어나고 있다.
#
# 그 중, 가장 보편적으로 사용되고 있는 인공지능의 기술은 자동번역 및 통역 등을 처리해주는 ***자연언어 처리 기술*** 이다.
#
# 과거에는 ***통계 기반 기계번역(SMT)*** 방식으로, 단어나 문맥을 제대로 파악하지 못해 오역되거나 해석할 수 없어, 자연스럽지 않은 번역의 티가 많이 났다. 하지만, 지금은 ***인공 신경망(NMT)*** 기반으로 기술이 발달하면서 실생활에서 활용될 만한 수준의 통 번역본은 물론 더욱더 인간의 언어에 가까운 말투로 문장을 번역해 주고 있다.
#
# ## 인공지능 데이터셋
# 지난 2016년, 이세돌과 알파고의 바둑대결은 전세계적으로 큰 이슈가 되었다. 최근, 알파고를 탄생시킨 구글에서 인공지능 학습을 위한 수만 개의 데이터셋을 무료로 공개했다. 이를 통해 사람과 더욱 비슷한 수준으로 자연스럽게 말하는 인공지능을 구현하겠다는 전략이다.
#
# #### (1) 구글, 대화용 AI 데이터셋
# 구글에서 공개한 데이터셋은 ‘CCPE’와 ‘태스크마스터-1’로, 여러 상황에 맞는 대화 내용을 AI가 학습할 수 있도록 보다 현실적이고 다양한 대화를 담은 것이 특징이다. 무엇보다 구글이 AI 관련 기술과 데이터를 무료로 공개한 것으로, AI 업계에 큰 전환점을 제시했다는 평을 받고 있다.
#
# [구글 데이터셋](https://datasetsearch.research.google.com/)
#
# #### (2) LG CNS, 한국어 질문에 대한 데이터셋
#
# 국내에서도 최근 다량의 AI 학습용 데이터셋을 공개했다. LG CNS가 공개한 ‘KorQuAD'는 1,550개의 Wikipedia Article에 대해 10,649건의 하위 문단과 클라우드 소싱을 통해 제작한 질의응답 등 한국어 표준데이터 10만 개 가량이 담겨 AI가 장문의 답변을 하는 데 활용된다.
#
# 무엇보다 AI 학습에 필요한 영어 표준 데이터는 다양한 자료들이 있었지만, 국내에는 한국어 표준 데이터가 거의 존재하지 않았다는 점에서 향후 한국어를 활용한 AI 서비스 발전에 도움이 될 것이다.
#
# ## Travis, ‘Touch Plus’
# 트래비스의 ***터치 플러스*** 는 양방향 통역기로 인공지능을 통해 100개 이상의 언어를 실시간으로 번역한다. 또 와이파이 및 4G SIM 카드 슬롯을 내장해 자유로운 사용이 가능하며, 핫스팟을 켜면 스마트폰과 데이터를 나눠 사용할 수도 있다. 여기에 대화모드를 지원해 두 가지 언어를 동시에 통역할 수 있으며, 2500mAh의 대용량 배터리를 탑재해 1회 충전으로 최대 12시간 동안 사용이 가능하다.
# ![트래비스 터치 플러스](https://img.appstory.co.kr/@files/monthly.appstory.co.kr/content/201905/d322e36dcc6454e9d051ffe5a22c6bb9.jpg)
#
# ---
#
# # 2. 음성
# 인공지능 제품이나 서비스를 떠올릴 때, 너무 당연하다고 인식되는 기능이 바로 ***음성인식*** 이다. 음성인식 기술은 최근 빠른 발전을 이뤄냈고 우리에게 편리함을 제공해주고 있다.
#
# 스마트폰의 음성 기반 인공지능 비서는 이름만 불러도 기다렸다는 듯 인사를 건넨다. 차 안에 한 대씩은 있는 자동차 내비게이션은 물론 인공지능 스피커도 최근에는 흔히 볼 수 있게 되었다. 덕분에 말 한마디를 건네서 날씨나 지리 정보를 쉽게 얻을 수 있고 기계와 농담까지 주고받을 수 있게 되었다.
#
# ![네이버 라인 스피커](https://lh3.googleusercontent.com/proxy/FU9039x7kd8GT4Cv17_BHFbTp_ud-mI6h26rqG1iQfozSIISI-CoxZ7cN2QJIQuIt3QUBeyFS3svAyrEM7z1nGIb-rOoIdWCaWScUj6Kj2OGMwJ7cNY62XDt6emmgw)
#
# ![카카오 스피커](https://www.bloter.net/wp-content/uploads/2018/08/kakao-mini-C_2-800x527.jpg)
#
# ## 기계가 사람의 말을 이해하는 방법
#
# 우리가 인공지능 기반 음성인식 제품에 말을 하면, ***음성 입력 및 인식 → 자연어 처리 → 인식 결과*** 의 단계를 거친다. 이 과정은 기계가 사람의 언어를 인식하고 이해하기 위해 필요한 과정이다.
#
#
# 첫 번째 과정에서는 음성 입력 과정을 거쳐 사람의 음성을 컴퓨터가 이해할 수 있도록 텍스트화 한다.
#
# 이 기술을 ***STT(Speech To Text)*** 라고 한다. 어린아이가 받아쓰기를 하듯이 사람의 음성을 텍스트로 옮기는 것이다. 주변 소음을 제외한 말소리를 파악하고 이어서 각 발음과 단어를 인식한 후 핵심어와 연결 단어를 인식해 입력해야 하므로 생각보다 간단하고 쉽지만은 않다.
#
# 두 번째는 ***자연어 처리(Natural Language Processing, NLP)*** 과정이다. 자연어란 사람이 의사소통을 위해 사용하는 언어이다. 자연어 처리란 컴퓨터가 자연어를 분석하여 이해하고 처리하는 기술이다.
#
# 이 과정에서는 자연어에 대한 형태소 분석, 구문 해석, 의미 분석, 화용 분석 등을 통해 컴퓨터가 문장에 담긴 의도를 파악하게 한다. 이 자연어 처리는 인공지능의 주요 분야로, 인공지능 기계가 사람의 언어를 얼마나 잘 파악하였는지를 알 수 있는 과정이다.
#
# 앞선 과정을 거쳐 마지막으로 기계는 인식 결과를 출력한다. 인식된 요청에 따라 가장 최적의 결과를 찾아내고, ***TTS(Text to Speech)*** 기술을 통해 사람의 말소리처럼 응답하는 것이다. 친구에게 메시지를 보내라고 말했다면 전달한 내용으로 메시지를 전송하고, 날씨를 물어봤다면 인터넷에서 위치 기반의 날씨를 검색해 대답해준다.
#
# ---
#
# # 3. 이미지
#
# “오늘 날씨 어때?” 음성을 인식하는 인공지능은 AI 스피커, 각종 가전제품 등에 적용되며 우리의 일상으로 자리 잡았다. 말 한마디면 내가 원하는 것을 척척 들어주는 음성인식 인공지능(AI) 덕분에 가능해진 일이다.
#
# 이처럼 인공지능의 기술은 음성을 인식하는 것뿐만 아니라 사람의 눈을 대체하여 시각적으로 보는 것까지 인식할 수 있는 기술까지 발전했다.
#
# ## 사물을 보고 스스로 인식하는 AI 이미지 분석 기술
#
# 이미지 분석 기술은 기존에도 컴퓨터 비전(Computer Vision)을 중심으로 연구되어 온 분야였다. 이것이 최근에는 더욱 발전된 인공신경망 기술인 딥러닝(Deep Learning)을 통해 사람의 시각처럼 높은 정확도와 다양한 사물 인식이 가능한 AI 이미지 분석으로 한 단계 진화하여 등장했다.
#
# 인물이나 피사체의 움직임을 정교하게 인식하여 촬영하는 스마트폰의 카메라, 사진을 ‘음식’, ‘동물’ 등으로 자동 분류해 주는 구글 포토, 카메라를 비추면 어떤 사물인지 알려주는 구글 렌즈 등이 실생활에서 찾아볼 수 있는 AI 이미지 분석 기술의 사례이다.
#
# ## 이미지 분석의 관건, 노이즈 분석하기
#
# AI 이미지 분석의 핵심 기술은 바로 ***노이즈(Noise)*** 를 얼마나 판별해 내느냐 하는 것이다.
#
# 예를 들어, 판다(동물) 사진에 노이즈를 삽입했을 경우, 사람은 여전히 판다로 정확히 판단하지만, AI는 각각의 데이터(픽셀)로 이미지를 분석하기 때문에 긴팔원숭이로 잘못 인식하는 경우가 있다.
#
# ![판다 노이즈 분석](https://post-phinf.pstatic.net/MjAxOTAyMTRfMjA4/MDAxNTUwMTI1MTQzMDAx.wGsI-RL_cF1VV4JZZDWcUX8MDQmkPseSQTWhyvN3G5wg.TtxD6YS2_Je9IhEb4crpjqoELsK5E6_05DZA6mBAOlUg.JPEG/0214_AI-%EC%9D%B4%EB%AF%B8%EC%A7%80-%EB%B6%84%EC%84%9D_03-720x3601.jpg?type=w1200)
#
# ![노이즈 분석](https://post-phinf.pstatic.net/MjAxOTAyMTRfMTEy/MDAxNTUwMTI1MTU0NjQ4.ZV3VK6tjC9Blfjq8M0e5Utdr_UcYR057aruFv8tdjD8g.Tz-AB95sI4fWA2fA5mJBsVIMP3K6vVqELo2i1T39eLkg.JPEG/0214_AI-%EC%9D%B4%EB%AF%B8%EC%A7%80-%EB%B6%84%EC%84%9D_04-720x10801.jpg?type=w1200)
#
# 또한, 노이즈는 아니지만 객체의 구도와 모양, 그리고 색이 유사하여 이미지 분석을 혼란스럽게 만드는 경우들도 있다. 모양이나 질감이 유사한 경우, 위 사진처럼 푸들을 치킨으로, 치와와를 머핀으로, 풀리를 청소도구로 잘못 인식하는 문제가 발생할 수 있다.
#
# ## 이미지 분석의 활용 분야
#
# 인공지능을 통한 이미지 분석이 각광받고 있는 것은 다양한 산업 분야에 활용할 수 있기 때문이다. 생산시설, 무인 스토어, 보안 검색대까지 AI 이미지 분석은 유용함을 넘어 이제 필수로 여겨지고 있다.
#
# #### (1) 스마트 팩토리
# 전자제품에 들어가는 유리기판 제조 생산 공장에서는 부품 불량의 원인이 되는 기포와 먼지를 구별해 내는 것이 매우 중요하다. AI 이미지 분석 기술이 스마트팩토리에 적용되면 사람이 일일이 확인하는 것보다 오류 발생 확률을 현저히 낮추고 불량 판정률을 높일 수 있게 된다.
#
# #### (2) 보안 검색대
# 기존의 보안 검색대는 물건을 올리면 엑스레이로 촬영하여 사람이 이를 하나하나 판별해야 했다. 여기에 AI 이미지 분석 기술이 적용되면 보다 정확하게 촬영 이미지를 분석하여 반·출입 불허 물품을 자동으로 검색할 수 있게 된다.
#
# ---
#
# # 4. 자율주행
# 자율주행차량은 사람의 개입없이 처음부터 끝까지 차량 스스로의 판단만으로 운행이 가능해야 한다는 궁극적인 목표로 향해 가고 있다. 국제자동차기술자협회(Society of Automotive Engineers: SAE)의 자율주행 6단계에 따르면 자동차가 전혀 없는 0단계에서 어떤 상황에서도 완전자율주행이 가능한 5단계로까지 나눠지는데, 각 단계별로 풀어야하는 문제가 존재한다. 여러 회사들이 제한된 자율주행이 가능한 3단계와 특정 상황을 제외한 나머지 상황에서 완전자율주행이 가능한 4단계를 놓고 치열한 경쟁을 벌이고 있지만, 최근에 자율주행 시험 차량 보급이 늘어나면서 여러가지 한계점이 드러나고 있으며 이를 극복하기 위한 다양한 수단도 함께 등장하고 있다.
# ![단계별 자율주행 자동차 분류](https://img1.daumcdn.net/thumb/R720x0.q80/?scode=mtistory2&fname=http%3A%2F%2Fcfile10.uf.tistory.com%2Fimage%2F99A2A83B5CCA88BF257C21)
#
# ### (1) Google
# 미국의 자율주행 대표기업으로는 Google, GM, Ford, Delphi, Apple, UBER, NVIDIA 등이 있다. 그 중 자율주행 기술 확보에 가장 많이 투자하는 기업 중 하나가 Google이다. 현재까지 150만 마일 이상의 자율운전 데이터를 축적해 오고 있다.최근에는 미국 NHTSA로부터 무인운전 시스템이 법적인 운전자로 인정된다는 해
# 석을 얻어내기도 해 미국의 자율주행 산업을 주도해 가고 있다. 자율주행 산업에 대한 Google의 접근은 어떤 하드웨어도 직접 제작하지 않는다는 점에서 다른 기업들과의 차별화를 두고 있다.
# ![구글 자율주행차](https://pds.joins.com/news/component/htmlphoto_mmdata/201603/19/htm_2016031914350738002.jpg)
#
# ### (2) GM
# 제너럴 모터스(GM)의 자율주행 사업부문인 ‘크루즈(Cruise)’가 혼다자동차, GM 등과 협력해 개발한 자율주행자동차 ‘크루즈 오리진(Cruise Origin)’을 공개했다. 크루즈 오리진은 차량 공유 서비스를 위해 설계된 자동차로, 여러명의 승객이 함께 탑승할 수 있도록 셔틀 모양을 하고 있다. SUV 차량과도 유사하며, 운전대와 페달은 없다. 내부 인테리어는 방 분위기를 연출했고, 서로 마주 볼수 있도록 좌석을 배치했다. 각각의 좌석에는 개인용 USB 포트를 제공하며 여행 정보를 제공하기 위한 디지털 디스플레이를 차량 상단에 탑재하고 있다.
# ![GM 자율주행차](https://www.thedrive.co.kr/news/data/20200129/p1065574777432162_410_thum.PNG)
